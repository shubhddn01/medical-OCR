# %%
from pdf2image import convert_from_path
import cv2
from PIL import Image

# %%
pages = convert_from_path(r'docs/prescription/pre_1.pdf')

# %%
pages[0].show()

# %%
import pytesseract

# %%
text=pytesseract.image_to_string(pages[0])
print(text)
# Out:
# Dr John Smith, M.D
# 2 Non-Important Street,
# New York, Phone (000)-111-2222
#
# Name: Maria Sharapova Date: 5/11/2022
#
# Address: 9 tennis court, new Russia, DC
#
# —moemennannennemneneunmnmnnnnie sisson aNd eennteinenarnrnen:
#
# Prednisone 20 mg
# Lialda 2.4 gram
#
#
#
#
#
# 3 days,
#
# or 1 month

# %%
import numpy as np

def preprocess_image(img):
    gray = cv2.cvtColor(np.array(img),cv2.COLOR_BGR2GRAY)
    resized_img=resized=cv2.resize(gray,None,fx=1.5,fy=1.5,interpolation=cv2.INTER_LINEAR)
    processed_img=cv2.adaptiveThreshold(
        resized_img,
        255,
        cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
        cv2.THRESH_BINARY,
        61,
        11    
    )
    return processed_img;

# %%
img=preprocess_image(pages[0])

# %%
Image.fromarray(img)
# Out:
# <PIL.Image.Image image mode=L size=2550x3300 at 0x7D8057142940>

# %%
text=pytesseract.image_to_string(img)
print(text)
# Out:
# Dr John Smith, M.D
# 2 Non-Important Street,
# New York, Phone (000)-121-2222
#
# Name: Marta Sharapova Date: 5/11/2022
#
# Address: 9 tennis court, new Russia, DC
#
# K
#
#
#
# Prednisone 20 mg
# Lialda 2.4 gram
#
# Directions:
#
# Prednisone, Taper 5 mg every 3 days,
# Finish in 2.5 weeks a
# Lialda - take 2 pill everyday for 1 month
#
# Refill: 2 times
